# %%
import hypervariable_sites as hs

hs.get_hyparvariable_sites(path="/home/aliya/bioinf/sun_bear/HMA_alignment _repetitive_excl.fasta", 
                           count_boundary=2, 
                           frequency_boundary=0.1)
# Out:
# ([], 'See additional info in hypervariable_sites.csv')
